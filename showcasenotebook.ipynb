# %%
import sys
sys.path.append("./Functions")
from DataModel import Gaivota
from RealDistances import add_airports_distances
sys.path.append("./Tests")
from test_gaivota import test_distance_between_same_airport, test_calculate_distance_between_airports_type_checking, test_distance_between_distant_airports, test_distance_between_close_airports, test_calculate_distance_type_checking

# %%
test = Gaivota()
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.

# %% [markdown]
# ### Calculating distances between airports

# %%
calculate_distance_between_airports('LIS','TER') #Lisboa Ilha Terceira
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.
# 1554.052711793919

# %%
calculate_distance_between_airports('LIS','MAD') #Lisboa Madrid
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.
# 512.8839403664687

# %%
calculate_distance_between_airports('LIS','RAK') #Lisboa Marrakesh
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.
# 803.9700297006914

# %%
add_airports_distances(test)
routes = test.airports_distances
routes.head(5)
# Out:
#   Origin Destination    Distance
# 0    GKA         MAG  106.713899
# 0    GKA         HGU  124.481044
# 0    GKA         LAE  157.101505
# 0    GKA         POM  424.592807
# 0    GKA         WWK  337.022543

# %%
test_distance_between_distant_airports()
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test_distance_between_distant_airports()
#
# File ~\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Tests\test_gaivota.py:19, in test_distance_between_distant_airports()
#      16 def test_distance_between_distant_airports():
#      17     # Test when source and destination airports are distant from each other
#      18     distance = calculate_distance_between_airports('JFK', 'MAG')
# ---> 19     assert distance == pytest.approx(13000, rel=0.05)
#
# AssertionError:

# %% [markdown]
# - Unit test conclude with sucess, result was supose to be 14445 (tolerance of 5%). AssertionError

# %%
test_distance_between_same_airport()
# Out:
# airlines.csv already exists.
# airplanes.csv already exists.
# airports.csv already exists.
# routes.csv already exists.

# %% [markdown]
# - This test function applies this call: calculate_distance_between_airports('JFK', 'JFK') so there is no error which is expected

# %% [markdown]
# ### Method: plot airports by country

# %%
test.plot_airports_by_country('Angola')
# Out:
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:149: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:152: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   world[world.name.str.contains(country_name, case=False)].plot(
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:155: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   gdf_airports.plot(axes=axes, marker='o', color='blue', markersize=25, label='-Airport')

# %% [markdown]
# ### Method: Plot the distribution of flight distances for all flights

# %%
test.distance_analysis()

# %% [markdown]
# ### Method: plot internal flights

# %%
test.internal_airport('LIS', False)
# Out:
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:300: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ### Method of most used airplane models

# %%
test.plot_most_used_airplane_models(countries='Angola',top_n=10)

# %% [markdown]
# ### Method: plot internal flights

# %%
test.internal_country2('Portugal', False)
# Out:
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:450: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:455: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   gdf_airports.plot(axes=axes, marker='o', color='red', markersize=50, label='Airports')
# C:\Users\joaol\OneDrive - Nova SBE\MSc_BA\2nd semester\ADPRO\testz\./Functions\DataModel.py:459: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   gdf_flights.plot(axes=axes, color='blue', linewidth=2, linestyle='dashed', label='Flights')

# %%
test.aircrafts()
# Out:
# List of Aircraft Models:
# Aerospatiale (Nord) 262
# Aerospatiale (Sud Aviation) Se.210 Caravelle
# Aerospatiale SN.601 Corvette
# Aerospatiale/Alenia ATR 42-300
# Aerospatiale/Alenia ATR 42-500
# Aerospatiale/Alenia ATR 42-600
# Aerospatiale/Alenia ATR 72
# Airbus A300
# Airbus A300-600
# Airbus A300-600ST Super Transporter / Beluga
# Airbus A310
# Airbus A318
# Airbus A319
# Airbus A319neo
# Airbus A320
# Airbus A320neo
# Airbus A321
# Airbus A321neo
# Airbus A330
# Airbus A330-200
# Airbus A330-300
# Airbus A330-700 Beluga XL
# Airbus A330-800neo
# Airbus A330-900neo
# Airbus A340
# Airbus A340-200
# Airbus A340-300
# Airbus A340-500
# Airbus A340-600
# Airbus A350
# Airbus A350-1000
# Airbus A350-900
# Airbus A380
# Airbus A380-800
# Antonov AN-12
# Antonov AN-124 Ruslan
# Antonov AN-140
# Antonov An-148
# Antonov An-158
# Antonov An-225 Mriya
# Antonov AN-24
# Antonov AN-26
# Antonov AN-28
# Antonov AN-30
# Antonov AN-32
# Antonov AN-72
# Avro RJ100
# Avro RJ70
# Avro RJ85
# ...

# %%
test.aircraft_info("Airbus")
# Out:
# Aircraft model 'Airbus' not found in the data.
# Similar aircraft models:
# Airbus A300
# Airbus A300-600
# Airbus A300-600ST Super Transporter / Beluga
# Airbus A310
# Airbus A318
# Please choose a valid aircraft name from the list above.

# %%
test.aircraft_info("Airbus A300")
# Out:
# C:\Users\joaol\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# | Specification           | Details                                      |
# |-------------------------|----------------------------------------------|
# | Manufacturer            | Airbus                                       |
# | First flight            | October 28, 1972                             |
# | Introduction            | May 30, 1974                                 |
# | Role                    | Wide-body jet airliner                       |
# ...

# %%
test.airport_info("Mount Hagen Kagamuga Airport")
# Out:
# C:\Users\joaol\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(
# | Category            | Information                            |
# |---------------------|----------------------------------------|
# | Location            | Mount Hagen, Western Highlands Province, Papua New Guinea |
# | IATA code           | HGU                                    |
# | ICAO code           | AYMH                                   |
# | Elevation           | 5,741 feet                             |
# | Runways             | 1                                      |
# ...
